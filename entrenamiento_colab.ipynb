# %% [markdown]
# # Entrenamiento de Matriculas
#
# https://universe.roboflow.com/put-poznan-6aps1/car_detect-chuwy

# %%
# Para montar el drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Para instalar ultralytics y comprobar el hardware
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.24 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.9/78.2 GB disk)

# %%
#ruta del directorio para entrenar y almacenar

ruta = "/content/drive/MyDrive/Pasantia/car_detect"
ruta_yaml = ruta + "/data.yaml"
destination_dir = ruta + "/40epocas"

# %%
#Entrenamiento

from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(data=ruta_yaml, epochs=40, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 21.4MB/s]
# Ultralytics YOLOv8.2.24 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# para copiar carpetas dentro del drive
import shutil

# Directorio de origen que deseas copiar
source_dir = '/content/runs/detect'

# Directorio de destino en Google Drive
destination_dir

# Copiar la carpeta al directorio de destino en Google Drive
shutil.copytree(source_dir, destination_dir)
# Out:
# '/content/drive/MyDrive/Pasantia/car_detect/40corridas'
